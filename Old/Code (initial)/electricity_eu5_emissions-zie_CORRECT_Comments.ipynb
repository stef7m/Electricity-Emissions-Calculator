# %%
import pandas as pd
import requests
import itertools
import csv

# %%
# Creating my personal API request

url = "https://www.carboninterface.com/api/v1/estimates"
headers = {
    "Authorization": "Bearer jc98IgLeY6KvaRIcifjFnw",
    "Content-Type": "application/json",
}

# %%
# Defining the possible values for each parameter

electricity_values = list(range(1, 6))
countries = ["UK","PT","IT","NL","ES"]
electricity_units = ["kwh"]
_type = "electricity"

# %%
# Initializing an empty list to store the generated data

all_data = []

# %%
for electricity_value, country, electricity_unit in itertools.product(electricity_values, countries, electricity_units):
    print({
        "type": "electricity",
        "electricity_unit": electricity_unit,
        "electricity_value": electricity_value,
        "country": country.lower(),
    })
# Out:
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'uk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'pt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'it'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'nl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'es'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'uk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'pt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'it'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'nl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'es'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'uk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'pt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'it'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'nl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'es'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'uk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'pt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'it'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'nl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'es'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'uk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'pt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'it'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'nl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'es'}

# %%
'''Hi guys please remove comment after reading, thanks
        So the api response is in the form :
        # {'data': 
        #   {'id': '20d75907-5e90-4942-b32a-77cd24a1168b', 
        #    'type': 'estimate', 
        #    'attributes': {
            #       'country': 'at', 
            #       'state': None, 
            #       'electricity_unit': 'kwh', 
            #       'electricity_value': 1.0, 
            #       'estimated_at': '2024-01-30T03:34:28.498Z', 
            #       'carbon_g': 83, 
            #       'carbon_lb': 0.18, 
            #       'carbon_kg': 0.08, 
            #       'carbon_mt': 0.0
            # }}}
            
        But notice in the original code below, we are referencing an inner dict "carbon" which does not exist hence we get 
            "No carbon data received."
            # carbon_data = response.json().get("data", {}).get("attributes", {}).get(**"carbon"**, {}).get("value")
            
        So we need to just get the response json data attributes key and set that to carbon data
            data = response.json().get("data", {})'''
# Out:
# 'Hi guys please remove comment after reading, thanks\n        So the api response is in the form :\n        # {\'data\': \n        #   {\'id\': \'20d75907-5e90-4942-b32a-77cd24a1168b\', \n        #    \'type\': \'estimate\', \n        #    \'attributes\': {\n            #       \'country\': \'at\', \n            #       \'state\': None, \n            #       \'electricity_unit\': \'kwh\', \n            #       \'electricity_value\': 1.0, \n            #       \'estimated_at\': \'2024-01-30T03:34:28.498Z\', \n            #       \'carbon_g\': 83, \n            #       \'carbon_lb\': 0.18, \n            #       \'carbon_kg\': 0.08, \n            #       \'carbon_mt\': 0.0\n            # }}}\n            \n        But notice in the original code below, we are referencing an inner dict "carbon" which does not exist hence we get \n            "No carbon data received."\n            # carbon_data = response.json().get("data", {}).get("attributes", {}).get(**"carbon"**, {}).get("value")\n            \n        So we need to just get the response json data attributes key and set that to carbon data\n            data = response.json().get("data", {})'

# %%
# Generating all combinations of parameters
for electricity_value, country, electricity_unit in itertools.product(electricity_values, countries, electricity_units):
    data_entry = {
        # Input data
        "electricity_unit": electricity_unit,
        "electricity_value": electricity_value,
        "country": country.lower(),
        "type": _type,
    }

    # Making API request to get carbon values
    response = requests.post(url, headers=headers, json=data_entry)

    if response.status_code == 201:
        # Extract relevant information from the response
        estimate_id = response.json().get("data", {}).get("id")
        if estimate_id:
            print(f"Estimate created successfully with ID: {estimate_id}")
    
        carbon_data = response.json().get("data", {}).get("attributes", {}) # I deleted here
        if carbon_data is not None:
            data_entry.update(carbon_data) # then changed here to update data_entry with the carbon_data 
                                            # dict which is the attributes dict inside reponse
            # Append the data entry to the list
            all_data.append(data_entry)
            print("Data appended successfully.")
        else:
            print("No carbon data received.")
            # Check if carbon data is present  
    else:
        print(f"API request failed for: {data_entry}, status code: {response.status_code}")
# Out:
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'uk', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 6e7ca163-7824-4940-9ff0-19d304b225d1
# Data appended successfully.
# Estimate created successfully with ID: 0dd1dbce-1a46-44da-8d17-0c8b925b18f8
# Data appended successfully.
# Estimate created successfully with ID: be3a4233-0992-4987-bf05-b19093e987ff
# Data appended successfully.
# Estimate created successfully with ID: 2927f4a5-8198-46ec-9753-ebee79b0579e
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'uk', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 865bd293-a6a1-4d81-ac7d-bf2657b3e927
# Data appended successfully.
# Estimate created successfully with ID: bdbd6048-7e0a-42d2-abdb-bbbbef36ae1d
# Data appended successfully.
# Estimate created successfully with ID: fc3db159-7fa4-4288-84ad-7bf65e5c2aa3
# Data appended successfully.
# Estimate created successfully with ID: f4d301df-7169-4fd1-93fb-4411baa011c1
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'uk', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: cbab9602-d99a-40ac-95c3-03490a06581c
# Data appended successfully.
# Estimate created successfully with ID: 117e4793-f229-4ba0-b4ae-7a0922ac967b
# Data appended successfully.
# Estimate created successfully with ID: d0866e19-c032-437c-872b-8e48b17c1e8a
# Data appended successfully.
# Estimate created successfully with ID: f815d3b0-a464-46c1-b78b-99aca44aca47
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'uk', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 8d0a2a68-17ee-4eab-ae92-de0c353c95e1
# Data appended successfully.
# Estimate created successfully with ID: 06c3fbff-bb31-45dd-8433-a4700aaee477
# Data appended successfully.
# Estimate created successfully with ID: 73c9c45b-6d93-4f92-81ee-b7263ade69ff
# Data appended successfully.
# Estimate created successfully with ID: e8a01ec9-da8e-4b7c-92fe-cf781a9594ca
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'uk', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: fa9aa0cf-7f6b-4918-baf9-b334b61b8e2a
# Data appended successfully.
# Estimate created successfully with ID: dae27cb8-1fdd-42b3-a6f7-3e6cedd1a293
# Data appended successfully.
# Estimate created successfully with ID: 8bf690da-1223-4b08-b69b-9ffbebd88f11
# Data appended successfully.
# Estimate created successfully with ID: d4fd2e9d-a6e1-4098-9864-16530811e2b2
# Data appended successfully.

# %%
all_data
# Out:
# [{'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'pt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:19.518Z',
#   'carbon_g': 201,
#   'carbon_lb': 0.44,
#   'carbon_kg': 0.2,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'it',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:20.355Z',
#   'carbon_g': 212,
#   'carbon_lb': 0.47,
#   'carbon_kg': 0.21,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'nl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:20.913Z',
#   'carbon_g': 318,
#   'carbon_lb': 0.7,
#   'carbon_kg': 0.32,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'es',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:21.746Z',
#   'carbon_g': 190,
#   'carbon_lb': 0.42,
#   'carbon_kg': 0.19,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'pt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:22.955Z',
#   'carbon_g': 402,
#   'carbon_lb': 0.89,
#   'carbon_kg': 0.4,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'it',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:23.548Z',
#   'carbon_g': 424,
#   'carbon_lb': 0.93,
#   'carbon_kg': 0.42,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'nl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:24.362Z',
#   'carbon_g': 636,
#   'carbon_lb': 1.4,
#   'carbon_kg': 0.64,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'es',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:25.138Z',
#   'carbon_g': 380,
#   'carbon_lb': 0.84,
#   'carbon_kg': 0.38,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'pt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:26.554Z',
#   'carbon_g': 603,
#   'carbon_lb': 1.33,
#   'carbon_kg': 0.6,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'it',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:27.101Z',
#   'carbon_g': 636,
#   'carbon_lb': 1.4,
#   'carbon_kg': 0.64,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'nl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:27.656Z',
#   'carbon_g': 954,
#   'carbon_lb': 2.1,
#   'carbon_kg': 0.95,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'es',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:28.412Z',
#   'carbon_g': 570,
#   'carbon_lb': 1.26,
#   'carbon_kg': 0.57,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'pt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:29.861Z',
#   'carbon_g': 804,
#   'carbon_lb': 1.77,
#   'carbon_kg': 0.8,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'it',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:30.686Z',
#   'carbon_g': 848,
#   'carbon_lb': 1.87,
#   'carbon_kg': 0.85,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'nl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:31.373Z',
#   'carbon_g': 1272,
#   'carbon_lb': 2.8,
#   'carbon_kg': 1.27,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'es',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:31.953Z',
#   'carbon_g': 760,
#   'carbon_lb': 1.68,
#   'carbon_kg': 0.76,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'pt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:33.307Z',
#   'carbon_g': 1005,
#   'carbon_lb': 2.22,
#   'carbon_kg': 1.01,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'it',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:33.908Z',
#   'carbon_g': 1060,
#   'carbon_lb': 2.34,
#   'carbon_kg': 1.06,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'nl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:34.722Z',
#   'carbon_g': 1590,
#   'carbon_lb': 3.51,
#   'carbon_kg': 1.59,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'es',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-03T19:03:35.421Z',
#   'carbon_g': 950,
#   'carbon_lb': 2.09,
#   'carbon_kg': 0.95,
#   'carbon_mt': 0.0}]

# %%
# Make sure to put the correct path
csv_file_path = "carbon_data.csv"

# %%
# Check if all_data is not empty before writing to CSV

if all_data:
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.DictWriter(csv_file, fieldnames=all_data[0].keys())
        csv_writer.writeheader()
        csv_writer.writerows(all_data)
    print(f"CSV data exported to: {csv_file_path}")
else:
    print("No data to export.")
# Out:
# CSV data exported to: carbon_data.csv

# %%
# Exporting to CSV

csv_file_path = "/Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ukptitnles_dataset.csv"

# Check if all_data is not empty before writing to CSV
if all_data:
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.DictWriter(csv_file, fieldnames=all_data[0].keys())
        csv_writer.writeheader()
        csv_writer.writerows(all_data)
    print(f"CSV data exported to: {csv_file_path}")
else:
    print("No data to export.")
# Out:
# CSV data exported to: /Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ukptitnles_dataset.csv

# %%
print(f"CSV data exported to: {csv_file_path}")
# Out:
# CSV data exported to: /Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ukptitnles_dataset.csv
