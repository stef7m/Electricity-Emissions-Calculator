# %%
import pandas as pd
import os

# %%
path=r'/Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/01. Data'

# %% [markdown]
# ## Importing EU electricity value 1 dataset as df_1 and checking outcome

# %%
df_1=pd.read_csv(os.path.join(path, 'electricity_eu_combined_trees.csv'),index_col=False)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   electricity_unit         28 non-null     object
#  1   electricity_value        28 non-null     float64
#  2   country abbreviation     28 non-null     object
#  3   type                     28 non-null     object
#  4   carbon_g                 28 non-null     float64
#  5   carbon_lb                28 non-null     float64
#  6   carbon_kg                28 non-null     float64
#  7   carbon_mt                28 non-null     float64
#  8   country                  28 non-null     object
#  9   trees required           28 non-null     float64
#  10  trees required in units  28 non-null     float64
# dtypes: float64(7), object(4)
# memory usage: 2.6+ KB

# %% [markdown]
# ### Checking df_1

# %%
df_1.head(29)
# Out:
#    electricity_unit  electricity_value country abbreviation         type  \
# 0               kwh                1.0                   at  electricity
# 1               kwh                1.0                   be  electricity
# 2               kwh                1.0                   bg  electricity
# 3               kwh                1.0                   hr  electricity
# 4               kwh                1.0                   cy  electricity
# 5               kwh                1.0                   cz  electricity
# 6               kwh                1.0                   dk  electricity
# 7               kwh                1.0                   ee  electricity
# 8               kwh                1.0                   fi  electricity
# 9               kwh                1.0                   fr  electricity
# 10              kwh                1.0                   de  electricity
# 11              kwh                1.0                   ie  electricity
# ...

# %%
df_1.shape
# Out:
# (29, 11)

# %% [markdown]
# ### Checking for Missing Values

# %%
df_1.isna().sum() # discovered that the last row is with NaN values
# Out:
# electricity_unit           1
# electricity_value          1
# country abbreviation       1
# type                       1
# carbon_g                   1
# carbon_lb                  1
# carbon_kg                  1
# carbon_mt                  1
# country                    1
# trees required             1
# trees required in units    1
# dtype: int64

# %%
# deleting the last row

df_1 = df_1.iloc[:-1]

# %%
# checking outcome

df_1.isna().sum()
# Out:
# electricity_unit           0
# electricity_value          0
# country abbreviation       0
# type                       0
# carbon_g                   0
# carbon_lb                  0
# carbon_kg                  0
# carbon_mt                  0
# country                    0
# trees required             0
# trees required in units    0
# dtype: int64

# %% [markdown]
# ### Checking for consistency

# %%
# checking for mixed type columns

for col in df_1.columns.tolist():
  weird = (df_1[[col]].applymap(type) != df_1[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_1[weird]) > 0:
    print (col)

# %% [markdown]
# ### Checking for duplicates

# %%
df_dups = df_1[df_1.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [electricity_unit, electricity_value, country abbreviation, type, carbon_g, carbon_lb, carbon_kg, carbon_mt, country, trees required, trees required in units]
# Index: []

# %% [markdown]
# ### Performing descriptive statistics

# %%
 df_1.describe()
# Out:
#        electricity_value    carbon_g  carbon_lb  carbon_kg  carbon_mt  \
# count               28.0   28.000000  28.000000  28.000000       28.0
# mean                 1.0  254.214286   0.560000   0.254286        0.0
# std                  0.0  190.189644   0.419312   0.189569        0.0
# min                  1.0   13.000000   0.030000   0.010000        0.0
# 25%                  1.0  110.000000   0.245000   0.112500        0.0
# 50%                  1.0  208.500000   0.460000   0.210000        0.0
# 75%                  1.0  326.500000   0.720000   0.327500        0.0
# max                  1.0  724.000000   1.600000   0.720000        0.0
#
#        trees required  trees required in units
# count       28.000000                28.000000
# mean         0.011643                 0.964286
# std          0.008685                 0.188982
# min          0.000000                 0.000000
# 25%          0.004750                 1.000000
# 50%          0.010000                 1.000000
# ...

# %% [markdown]
# ## Importing EU electricity value 2-50 dataset as df_2 and checking outcome

# %%
df_2=pd.read_csv(os.path.join(path, 'emissions_eu50_trees.csv'),index_col=False)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    1372 non-null   int64
#  1   electricity_unit         1372 non-null   object
#  2   country abbreviation     1372 non-null   object
#  3   type                     1372 non-null   object
#  4   carbon_g                 1372 non-null   int64
#  5   carbon_lb                1372 non-null   float64
#  6   carbon_kg                1372 non-null   float64
#  7   carbon_mt                1372 non-null   int64
#  8   country                  1372 non-null   object
#  9   electricity_value        1372 non-null   int64
#  10  trees_required           1372 non-null   float64
#  11  trees_required_in_units  1372 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 128.8+ KB

# %% [markdown]
# ### Checking df_2

# %%
df_2.head(15)
# Out:
#     Index electricity_unit country abbreviation         type  carbon_g  \
# 0       0              kwh                   at  electricity       166
# 1       1              kwh                   at  electricity       249
# 2       2              kwh                   at  electricity       332
# 3       3              kwh                   at  electricity       415
# 4       4              kwh                   at  electricity       498
# 5       5              kwh                   at  electricity       581
# 6       6              kwh                   at  electricity       664
# 7       7              kwh                   at  electricity       747
# 8       8              kwh                   at  electricity       830
# 9       9              kwh                   at  electricity       913
# 10     10              kwh                   at  electricity       996
# 11     11              kwh                   at  electricity      1079
# ...

# %%
df_2.shape
# Out:
# (1372, 12)

# %%
# dropping column Index to match df_1

df_2.drop(columns = ['Index'])
# Out:
#      electricity_unit country abbreviation         type  carbon_g  carbon_lb  \
# 0                 kwh                   at  electricity       166       0.36
# 1                 kwh                   at  electricity       249       0.54
# 2                 kwh                   at  electricity       332       0.72
# 3                 kwh                   at  electricity       415       0.90
# 4                 kwh                   at  electricity       498       1.08
# ...               ...                  ...          ...       ...        ...
# 1367              kwh                   hu  electricity     10028      22.08
# 1368              kwh                   hu  electricity     10246      22.56
# 1369              kwh                   hu  electricity     10464      23.04
# 1370              kwh                   hu  electricity     10682      23.52
# 1371              kwh                   hu  electricity     10900      24.00
#
# ...

# %% [markdown]
# ### Checking for Missing Values

# %%
df_2.isna().sum()
# Out:
# Index                      0
# electricity_unit           0
# country abbreviation       0
# type                       0
# carbon_g                   0
# carbon_lb                  0
# carbon_kg                  0
# carbon_mt                  0
# country                    0
# electricity_value          0
# trees_required             0
# trees_required_in_units    0
# dtype: int64

# %% [markdown]
# ### Checking for consistency

# %%
# checking for mixed type columns

for col in df_2.columns.tolist():
  weird = (df_2[[col]].applymap(type) != df_2[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_2[weird]) > 0:
    print (col)

# %% [markdown]
# ### Checking for duplicates

# %%
df_dups2 = df_2[df_2.duplicated()]

# %%
df_dups2
# Out:
# Empty DataFrame
# Columns: [Index, electricity_unit, country abbreviation, type, carbon_g, carbon_lb, carbon_kg, carbon_mt, country, electricity_value, trees_required, trees_required_in_units]
# Index: []

# %% [markdown]
# ### Performing descriptive statistics

# %%
 df_2.describe()
# Out:
#              Index      carbon_g    carbon_lb    carbon_kg  carbon_mt  \
# count  1372.000000   1372.000000  1372.000000  1372.000000     1372.0
# mean    685.500000   6609.571429    14.560000     6.611429        0.0
# std     396.206596   6596.346322    14.539382     6.581786        0.0
# min       0.000000     26.000000     0.060000     0.020000        0.0
# 25%     342.750000   2009.250000     4.407500     2.037500        0.0
# 50%     685.500000   4425.000000     9.800000     4.425000        0.0
# 75%    1028.250000   8910.500000    19.680000     8.962500        0.0
# max    1371.000000  36200.000000    80.000000    36.000000        0.0
#
#        electricity_value  trees_required  trees_required_in_units
# count        1372.000000     1372.000000              1372.000000
# mean           26.000000        0.300519                 1.045918
# std            14.147292        0.299172                 0.209384
# min             2.000000        0.000909                 1.000000
# ...

# %% [markdown]
# ## Combining df_1 and df_2

# %%
# concatenating both dfs along the rows since they have same columns

df_combined = pd.concat([df_1, df_2], ignore_index=True) # Setting ignore_index=True ensures that the index is reset after concatenation
