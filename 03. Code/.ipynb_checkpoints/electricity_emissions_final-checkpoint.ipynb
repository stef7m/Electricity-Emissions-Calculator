# %%
import pandas as pd
import requests
import itertools
import csv

# %%
# Creating my personal API request

url = "https://www.carboninterface.com/api/v1/estimates"
headers = {
    "Authorization": "Bearer jc98IgLeY6KvaRIcifjFnw",
    "Content-Type": "application/json",
}

# %%
# Defining the possible values for each parameter

electricity_values = list(range(1, 6))
countries = ["IE","LV","LT","LU","MT","PL","RO","SK","SW"]
electricity_units = ["kwh"]
_type = "electricity"

# %%
# Initializing an empty list to store the generated data

all_data = []

# %%
for electricity_value, country, electricity_unit in itertools.product(electricity_values, countries, electricity_units):
    print({
        "type": "electricity",
        "electricity_unit": electricity_unit,
        "electricity_value": electricity_value,
        "country": country.lower(),
    })
# Out:
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'ie'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'lv'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'lt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'lu'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'mt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'pl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'ro'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'sk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'sw'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'ie'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'lv'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'lt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'lu'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'mt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'pl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'ro'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'sk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'sw'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'ie'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'lv'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'lt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'lu'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'mt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'pl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'ro'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'sk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'sw'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'ie'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'lv'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'lt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'lu'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'mt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'pl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'ro'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'sk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'sw'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'ie'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'lv'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'lt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'lu'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'mt'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'pl'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'ro'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'sk'}
# {'type': 'electricity', 'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'sw'}

# %%
# Generating all combinations of parameters
for electricity_value, country, electricity_unit in itertools.product(electricity_values, countries, electricity_units):
    data_entry = {
        # Input data
        "electricity_unit": electricity_unit,
        "electricity_value": electricity_value,
        "country": country.lower(),
        "type": _type,
    }

    # Making API request to get carbon values
    response = requests.post(url, headers=headers, json=data_entry)

    if response.status_code == 201:
        # Extract relevant information from the response
        estimate_id = response.json().get("data", {}).get("id")
        if estimate_id:
            print(f"Estimate created successfully with ID: {estimate_id}")
    
        carbon_data = response.json().get("data", {}).get("attributes", {}) # I deleted here
        if carbon_data is not None:
            data_entry.update(carbon_data) # then changed here to update data_entry with the carbon_data 
                                            # dict which is the attributes dict inside reponse
            # Append the data entry to the list
            all_data.append(data_entry)
            print("Data appended successfully.")
        else:
            print("No carbon data received.")
            # Check if carbon data is present  
    else:
        print(f"API request failed for: {data_entry}, status code: {response.status_code}")
# Out:
# Estimate created successfully with ID: 8646d7e7-3e13-45f6-8aa5-1424a19f7a63
# Data appended successfully.
# Estimate created successfully with ID: d0af5eaf-269b-4021-9839-4ccb45e39478
# Data appended successfully.
# Estimate created successfully with ID: 79da307f-e188-47da-bdf1-211816e58b5d
# Data appended successfully.
# Estimate created successfully with ID: d7ebb0ca-e91a-4077-ad6a-f6ff4f5ffdce
# Data appended successfully.
# Estimate created successfully with ID: b4506931-1aac-4c4a-a34d-ed39cabde5ef
# Data appended successfully.
# Estimate created successfully with ID: 888a6e8d-dec9-4d47-94f8-68caaf0918dd
# Data appended successfully.
# Estimate created successfully with ID: abf735da-0df6-4b51-863a-e6b3a32174d9
# Data appended successfully.
# Estimate created successfully with ID: 149a441f-f1e9-4b01-9739-8bfef06efbd3
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 1, 'country': 'sw', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 135bdb12-8c65-4c32-b79f-a70e327397f2
# Data appended successfully.
# Estimate created successfully with ID: b5ac11de-d499-48c1-8c89-c82a7858df0a
# Data appended successfully.
# Estimate created successfully with ID: c6a140e3-18f2-4d52-9e04-8584bec76454
# Data appended successfully.
# Estimate created successfully with ID: ef16e4c2-761b-4cc4-a3d3-91e386079d2b
# Data appended successfully.
# Estimate created successfully with ID: 328a1b2f-ad5c-4431-97ee-e1ab57d45b1d
# Data appended successfully.
# Estimate created successfully with ID: 43edae82-b617-4fa1-a774-63cdb0a27cf9
# Data appended successfully.
# Estimate created successfully with ID: b547e5c1-1b2e-4df0-aef7-9eab2a62f7b7
# Data appended successfully.
# Estimate created successfully with ID: babceee1-0500-4383-92b5-9ba9fd2a1d6a
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 2, 'country': 'sw', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 34af330f-bb4b-4626-a22e-11c378aaa446
# Data appended successfully.
# Estimate created successfully with ID: 6c84cfb4-e12b-4c66-91b7-77431ea6dc62
# Data appended successfully.
# Estimate created successfully with ID: c5bcf1fa-96b4-4401-9d87-49dc8f83a356
# Data appended successfully.
# Estimate created successfully with ID: c6ff63b1-2adb-4608-b530-710e72f7754a
# Data appended successfully.
# Estimate created successfully with ID: 99cc88d7-2bb7-458c-b13d-04f193821791
# Data appended successfully.
# Estimate created successfully with ID: cdac67c1-5105-484b-bf65-a01e55622f4c
# Data appended successfully.
# Estimate created successfully with ID: f98d978b-1e01-4302-a215-96b34df102b7
# Data appended successfully.
# Estimate created successfully with ID: 292ace0f-cbba-4821-af10-7d07b6f815b9
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 3, 'country': 'sw', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: 2ab42655-1a11-4451-8b92-cc3d3907467c
# Data appended successfully.
# Estimate created successfully with ID: 221b872a-3a04-402c-b670-c0148c0109cc
# Data appended successfully.
# Estimate created successfully with ID: 160041c7-8152-4db6-b96b-b26f7225a159
# Data appended successfully.
# Estimate created successfully with ID: 710f7c30-29ce-4435-8294-cf939bb65aea
# Data appended successfully.
# Estimate created successfully with ID: 707f41e2-e496-420c-9f8c-ba78c077bf82
# Data appended successfully.
# Estimate created successfully with ID: 4646ef85-61d3-458b-bedb-60c09c8a282d
# Data appended successfully.
# Estimate created successfully with ID: bd04e9fb-3d3b-4821-9f9d-145b58172799
# Data appended successfully.
# Estimate created successfully with ID: aded8455-9a48-49e3-ac26-d4c86bab5b7b
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 4, 'country': 'sw', 'type': 'electricity'}, status code: 422
# Estimate created successfully with ID: c621bfc9-86d1-4485-b7ed-3b5597d216ec
# Data appended successfully.
# Estimate created successfully with ID: 733d3071-e878-42a2-8113-58d2243c3914
# Data appended successfully.
# Estimate created successfully with ID: 1887af8a-54c9-42e1-8188-95c91747a1be
# Data appended successfully.
# Estimate created successfully with ID: dc50ac25-0e88-44ea-862e-9f73bd37bf45
# Data appended successfully.
# Estimate created successfully with ID: 635d2360-24af-40b2-8874-b40920fcc53b
# Data appended successfully.
# Estimate created successfully with ID: 1d07bd4c-4552-463d-a28a-dfd166ed0b4f
# Data appended successfully.
# Estimate created successfully with ID: 38088a60-5727-47ec-aed0-452801f7abda
# Data appended successfully.
# Estimate created successfully with ID: 163f5513-d6a6-48a2-a9c7-90a2846d9fe3
# Data appended successfully.
# API request failed for: {'electricity_unit': 'kwh', 'electricity_value': 5, 'country': 'sw', 'type': 'electricity'}, status code: 422

# %%
all_data
# Out:
# [{'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'ie',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:15.142Z',
#   'carbon_g': 293,
#   'carbon_lb': 0.65,
#   'carbon_kg': 0.29,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'lv',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:15.921Z',
#   'carbon_g': 92,
#   'carbon_lb': 0.2,
#   'carbon_kg': 0.09,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'lt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:16.906Z',
#   'carbon_g': 146,
#   'carbon_lb': 0.32,
#   'carbon_kg': 0.15,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'lu',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:17.965Z',
#   'carbon_g': 69,
#   'carbon_lb': 0.15,
#   'carbon_kg': 0.07,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'mt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:18.979Z',
#   'carbon_g': 356,
#   'carbon_lb': 0.78,
#   'carbon_kg': 0.36,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'pl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:19.801Z',
#   'carbon_g': 724,
#   'carbon_lb': 1.6,
#   'carbon_kg': 0.72,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'ro',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:20.538Z',
#   'carbon_g': 208,
#   'carbon_lb': 0.46,
#   'carbon_kg': 0.21,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 1.0,
#   'country': 'sk',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:21.279Z',
#   'carbon_g': 90,
#   'carbon_lb': 0.2,
#   'carbon_kg': 0.09,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'ie',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:22.873Z',
#   'carbon_g': 586,
#   'carbon_lb': 1.29,
#   'carbon_kg': 0.59,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'lv',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:23.634Z',
#   'carbon_g': 184,
#   'carbon_lb': 0.41,
#   'carbon_kg': 0.18,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'lt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:24.304Z',
#   'carbon_g': 292,
#   'carbon_lb': 0.64,
#   'carbon_kg': 0.29,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'lu',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:25.243Z',
#   'carbon_g': 138,
#   'carbon_lb': 0.3,
#   'carbon_kg': 0.14,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'mt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:26.004Z',
#   'carbon_g': 712,
#   'carbon_lb': 1.57,
#   'carbon_kg': 0.71,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'pl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:26.858Z',
#   'carbon_g': 1448,
#   'carbon_lb': 3.19,
#   'carbon_kg': 1.45,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'ro',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:27.678Z',
#   'carbon_g': 416,
#   'carbon_lb': 0.92,
#   'carbon_kg': 0.42,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 2.0,
#   'country': 'sk',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:28.399Z',
#   'carbon_g': 180,
#   'carbon_lb': 0.4,
#   'carbon_kg': 0.18,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'ie',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:30.031Z',
#   'carbon_g': 879,
#   'carbon_lb': 1.94,
#   'carbon_kg': 0.88,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'lv',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:30.837Z',
#   'carbon_g': 276,
#   'carbon_lb': 0.61,
#   'carbon_kg': 0.28,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'lt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:31.768Z',
#   'carbon_g': 438,
#   'carbon_lb': 0.97,
#   'carbon_kg': 0.44,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'lu',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:32.421Z',
#   'carbon_g': 207,
#   'carbon_lb': 0.46,
#   'carbon_kg': 0.21,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'mt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:33.043Z',
#   'carbon_g': 1068,
#   'carbon_lb': 2.35,
#   'carbon_kg': 1.07,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'pl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:33.807Z',
#   'carbon_g': 2172,
#   'carbon_lb': 4.79,
#   'carbon_kg': 2.17,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'ro',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:34.577Z',
#   'carbon_g': 624,
#   'carbon_lb': 1.38,
#   'carbon_kg': 0.62,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 3.0,
#   'country': 'sk',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:35.313Z',
#   'carbon_g': 270,
#   'carbon_lb': 0.6,
#   'carbon_kg': 0.27,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'ie',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:36.930Z',
#   'carbon_g': 1172,
#   'carbon_lb': 2.58,
#   'carbon_kg': 1.17,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'lv',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:37.627Z',
#   'carbon_g': 368,
#   'carbon_lb': 0.81,
#   'carbon_kg': 0.37,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'lt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:38.353Z',
#   'carbon_g': 584,
#   'carbon_lb': 1.29,
#   'carbon_kg': 0.58,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'lu',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:39.118Z',
#   'carbon_g': 276,
#   'carbon_lb': 0.61,
#   'carbon_kg': 0.28,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'mt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:39.927Z',
#   'carbon_g': 1424,
#   'carbon_lb': 3.14,
#   'carbon_kg': 1.42,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'pl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:40.689Z',
#   'carbon_g': 2896,
#   'carbon_lb': 6.38,
#   'carbon_kg': 2.9,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'ro',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:41.441Z',
#   'carbon_g': 832,
#   'carbon_lb': 1.83,
#   'carbon_kg': 0.83,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 4.0,
#   'country': 'sk',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:42.328Z',
#   'carbon_g': 360,
#   'carbon_lb': 0.79,
#   'carbon_kg': 0.36,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'ie',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:44.481Z',
#   'carbon_g': 1465,
#   'carbon_lb': 3.23,
#   'carbon_kg': 1.47,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'lv',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:45.025Z',
#   'carbon_g': 460,
#   'carbon_lb': 1.01,
#   'carbon_kg': 0.46,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'lt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:45.789Z',
#   'carbon_g': 730,
#   'carbon_lb': 1.61,
#   'carbon_kg': 0.73,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'lu',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:46.598Z',
#   'carbon_g': 345,
#   'carbon_lb': 0.76,
#   'carbon_kg': 0.35,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'mt',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:47.406Z',
#   'carbon_g': 1780,
#   'carbon_lb': 3.92,
#   'carbon_kg': 1.78,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'pl',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:48.186Z',
#   'carbon_g': 3620,
#   'carbon_lb': 7.98,
#   'carbon_kg': 3.62,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'ro',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:48.919Z',
#   'carbon_g': 1040,
#   'carbon_lb': 2.29,
#   'carbon_kg': 1.04,
#   'carbon_mt': 0.0},
#  {'electricity_unit': 'kwh',
#   'electricity_value': 5.0,
#   'country': 'sk',
#   'type': 'electricity',
#   'state': None,
#   'estimated_at': '2024-02-23T15:45:49.639Z',
#   'carbon_g': 450,
#   'carbon_lb': 0.99,
#   'carbon_kg': 0.45,
#   'carbon_mt': 0.0}]

# %%
# Make sure to put the correct path
csv_file_path = "carbon_data.csv"

# %%
# Check if all_data is not empty before writing to CSV

if all_data:
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.DictWriter(csv_file, fieldnames=all_data[0].keys())
        csv_writer.writeheader()
        csv_writer.writerows(all_data)
    print(f"CSV data exported to: {csv_file_path}")
else:
    print("No data to export.")
# Out:
# CSV data exported to: carbon_data.csv

# %%
# Exporting to CSV

csv_file_path = "/Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ie_se_dataset.csv"

# Check if all_data is not empty before writing to CSV
if all_data:
    with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
        csv_writer = csv.DictWriter(csv_file, fieldnames=all_data[0].keys())
        csv_writer.writeheader()
        csv_writer.writerows(all_data)
    print(f"CSV data exported to: {csv_file_path}")
else:
    print("No data to export.")
# Out:
# CSV data exported to: /Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ie_se_dataset.csv

# %%
print(f"CSV data exported to: {csv_file_path}")
# Out:
# CSV data exported to: /Users/stefaniadaskalaki/pCloud Drive/02.Business/CHINGU/Voyage_47_team_30/Data/electricity_ie_se_dataset.csv
